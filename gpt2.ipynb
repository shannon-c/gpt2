# %% [markdown]
# <a href="https://colab.research.google.com/github/shannon-c/gpt2/blob/main/gpt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 60.5 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

#load pretrained model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model= GPT2LMHeadModel.from_pretrained("gpt2")

# %%
#set model to evaluation mode
model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
#prompt for text generation
prompt ="What is boba tea"

#encode prompt into input_ids
input_ids= tokenizer.encode(prompt, return_tensors='pt')

#generate output sequence using the model
output= model.generate(input_ids,
                       max_length=500,
                       do_sample= True,
                       num_return_sequences=1,
                       no_repeat_ngram_size=2,
                       early_stopping= True
                        )

#Decode putput sequence into text
generated_text = tokenizer.decode(output[0], skip_special_tokens= True)

#print generated text
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is boba tea, exactly?
#
# Not all bhojpuri is made from bhaal. Some are produced from bamboo shoots. These are generally good for digestion and help to retain body fat.
#
#
#
# boba
#  (left) and rice is often made with bhanjwa or pichitji. (right) But don't throw out the pimento when you are finished. It's quite good, especially if you have used a lot of bhut for cooking and cooked in advance. If you want to save that, simply leave the batter in the middle. I usually leave it at room temperature or just about 2-3 hours. You can make bhukshan using the traditional bhekkak or kaavak (but beware the old ones).
# ...
